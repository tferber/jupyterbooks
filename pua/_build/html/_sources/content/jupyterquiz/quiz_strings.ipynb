# %% [markdown]
# # Quiz Strings

# %%
from jupyterquiz import display_quiz

explanation = "'for letter in sentence' ist ein Generator-Ausdruck, der durch jeden Buchstaben in der Zeichenkette sentence iteriert. Für jeden Buchstaben (letter) in sentence wird überprüft, ob es sich um einen 'alphabetischen' Buchstaben (.isalpha()). Die Funktion all() prüft, ob alle Elemente im Iterable True sind. In diesem Fall ist das Iterable die Sequenz von booleschen Werten, die durch letter.isalpha() für jeden Buchstaben in sentence entstehen. Achtung: Leerzeichen sind keine alphabetischen Buchstaben!"

q1=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "sentence = \"Anyone who has never made a mistake has never tried anything new.\"\nresult = all(letter.isalpha() for letter in sentence)\nprint(result)",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "False",
                    "correct": True,
                    "feedback": "Richtig!"
                },
                {
                    "answer": "True",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
                {
                    "answer": "\"anyonewhohasnevermadeamistakehasnevertriedanythingnew\"",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
                {
                    "answer": "SyntaxError",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
            ]
    }]

explanation = "find() gibt den index des ersten Treffers zurück. Hierbei ist es case-sensititive. -1 wird nur dann zurückgegeben wenn es keinen Treffer gibt."
q2=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "text = \"Python is a powerful programming language.\"\nresult = text.find('p')\nprint(result)",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "0",
                    "correct": False,
                    "feedback": f"Falsch!  {explanation}"
                },
                {
                    "answer": "-1",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
                {
                    "answer": "12",
                    "correct": True,
                    "feedback": f"Richtig!"
                },
                {
                    "answer": "2",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
            ]
    }]

explanation = "find() kann mit optionalen Parametern aufgerufen die den String zuerst slicen und dort suchen. ! Mehr Info: https://docs.python.org/3/library/stdtypes.html#str.find"
q3=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "text = \"Python is a powerful programming language.\"\nresult = text.find('ogram', 10, 20)\nprint(result)",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "0",
                    "correct": False,
                    "feedback": f"Falsch!  {explanation}"
                },
                {
                    "answer": "-1",
                    "correct": True,
                    "feedback": f"Richtig! In diesem slice kommt 'ogram' nicht vor."
                },
                {
                    "answer": "23",
                    "correct": False,
                    "feedback": f"Falsch!  {explanation}"
                },
                {
                    "answer": "10",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
            ]
    }]

explanation = "Wie in der vorherigen Fragen wird die Suche in einem Slice durchgeführt - der Index wird aber relativ zum gesamten String zurückgegeben."
q4=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "text = \"Python is a powerful programming language.\"\nresult = text.find('g', text.find('prog'), text.find('language'))\nprint(result)",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "3",
                    "correct": False,
                    "feedback": f"Falsch!  {explanation}"
                },
                {
                    "answer": "24",
                    "correct": True,
                    "feedback": f"Richtig!"
                },
                {
                    "answer": "4",
                    "correct": False,
                    "feedback": f"Falsch!  {explanation}"
                },
                {
                    "answer": "-1",
                    "correct": False,
                    "feedback": f"Falsch! {explanation}"
                },
            ]
    }]


# explanation = "Der string wird mit split() bei jedem Leerzeichen gesplitten - bis zu einem Maximum von drei Splits!"
# q5=[{
#             "question": "Was ist das Ergebnis des folgenden Codes?",
#             "code": "text = \"Python is a powerful programming language.\"\nresult = sentence.split(' ', 3)\nprint(result)",
#             "type": "multiple_choice",
#             "answers": [
#                 {
#                     "answer": "'Python', 'is', 'a', 'powerful programming language.']",
#                     "correct": True,
#                     "feedback": "Richtig!"
#                 },
#                 {
#                     "answer": "['Python', 'is', 'a', 'powerful', 'programming language.']",
#                     "correct": False,
#                     "feedback": f"Falsch!  {explanation}"
#                 },
#                 {
#                     "answer": "['Python is a powerful', 'programming language.']",
#                     "correct": False,
#                     "feedback": f"Falsch!  {explanation}"
#                 },
#                 {
#                     "answer": "['Python', 'is', 'a', 'powerful', 'programming', 'language.']",
#                     "correct": False,
#                     "feedback": f"Falsch! {explanation}"
#                 },
#             ]
#     }]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from jupyterquiz import display_quiz
#       3 explanation = "'for letter in sentence' ist ein Generator-Ausdruck, der durch jeden Buchstaben in der Zeichenkette sentence iteriert. Für jeden Buchstaben (letter) in sentence wird überprüft, ob es sich um einen 'alphabetischen' Buchstaben (.isalpha()). Die Funktion all() prüft, ob alle Elemente im Iterable True sind. In diesem Fall ist das Iterable die Sequenz von booleschen Werten, die durch letter.isalpha() für jeden Buchstaben in sentence entstehen. Achtung: Leerzeichen sind keine alphabetischen Buchstaben!"
#       5 q1=[{
#       6             "question": "Was ist das Ergebnis des folgenden Codes?",
# ...

# %%
display_quiz(q1, colors='fdsp')
display_quiz(q2, colors='fdsp')
display_quiz(q3, colors='fdsp')
display_quiz(q4, colors='fdsp')
# display_quiz(q5, colors='fdsp')
