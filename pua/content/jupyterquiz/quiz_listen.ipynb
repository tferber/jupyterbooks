# %% [markdown]
# # Quiz Listen

# %%
from jupyterquiz import display_quiz

q1=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "my_list = [1, 2, 3, 4]\nprint(len(my_list))",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "1",
                    "correct": False,
                    "feedback": "Falsch! len() gibt die Zahl der Elemente der Liste zurück."
                },
                {
                    "answer": "2",
                    "correct": False,
                    "feedback": "Falsch! len() gibt die Zahl der Elemente der Liste zurück."
                },
                {
                    "answer": "3",
                    "correct": False,
                    "feedback": "Falsch! len() gibt die Zahl der Elemente der Liste zurück."
                },
                {
                    "answer": "4",
                    "correct": True,
                    "feedback": "Richtig!  len() gibt die Zahl der Elemente der Liste zurück."
                },
            ]
    }]


q2=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "meine_liste = [1, 2, 3, ]\nmeine_liste.append('Katze')\nmeine_liste.pop(2)",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "[1, 2, 'Katze']",
                    "correct": True,
                    "feedback": "Richtig!"
                },
                {
                    "answer": "[1, 2, 3, 'Katze']",
                    "correct": False,
                    "feedback": "Falsch! pop(2) entfernt den dritten Eintrag mit dem Index 2."
                },
                {
                    "answer": "[1, 3, 'Katze']",
                    "correct": False,
                    "feedback": "Falsch! pop(2) entfernt den Index 2, nicht den Wert 2, dafür nutzen sie remove(2)."
                },
                {
                    "answer": "SyntaxError",
                    "correct": False,
                    "feedback": "Falsch! Diese Operation ist gültiger Python Code."
                },
            ]
    }]

q3=[{
            "question": "Wiederholung: Was ist `b` am Ende des Codeblocks?",
            "code": "a=1\nb=a\na=4",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "b=4",
                    "correct": False,
                    "feedback": "Falsch! Variablen referenzieren immer einen Wert, in diesem Fall referenziert `b` welchen Wert?"
                },
                {
                    "answer": "b=1",
                    "correct": True,
                    "feedback": "Richtig!"
                },
                {
                    "answer": "b=None",
                    "correct": False,
                    "feedback": "Falsch! `None` ist reserviert für Datenobjekte ohne Typ. `b` referenziert allerdings ein Datenobjekt mit einem definierten Typ."
                },
            ]
    }]


q4=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "a=[1, 2, 3, ]\nb=a\na[-2]=5\nprint(b[1])",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "2",
                    "correct": False,
                    "feedback": "Falsch! Python lists sind `mutable`!"
                },
                {
                    "answer": "5",
                    "correct": True,
                    "feedback": "Richtig! Python lists sind `mutable`!"
                },
                {
                    "answer": "1",
                    "correct": False,
                    "feedback": "Falsch! a[-2] ist das vorletzte Element der Liste `a`, a[-1] das letzte."
                },
            ]
    }]


q5=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "a=[1, 3, 2, ]\nprint(a.reverse())",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "[2, 3, 1]",
                    "correct": False,
                    "feedback": "Falsch! reverse() ist eine void Funktion und hat den Rückgabewert None!"
                },
                {
                    "answer": "[1, 2, 3]",
                    "correct": False,
                    "feedback": "Falsch! reverse() ist eine void Funktion und hat den Rückgabewert None!"
                },
                {
                    "answer": "None",
                    "correct": True,
                    "feedback": "Richtig! reverse() ist eine void Funktion und hat den Rückgabewert None!"
                },
            ]
    }]


q6=[{
            "question": "Was ist das Ergebnis des folgenden Codes?",
            "code": "a=[3, 2, 4, 1, ]\na = a.sort\nprint(a[0])",
            "type": "multiple_choice",
            "answers": [
                {
                    "answer": "4",
                    "correct": False,
                    "feedback": "Falsch! sort() ist eine void Funktion mit None als Rückgabewert. Das erste Element (a[0]) ist kein gültiger Type."
                },
                {
                    "answer": "1",
                    "correct": False,
                    "feedback": "Falsch - allerdings haben sie richtig gedachte, dass sort() aufsteigend sortiert! sort() ist eine void Funktion mit None als Rückgabewert. Das erste Element (a[0]) ist kein gültiger Type."
                },
                {
                    "answer": "TypeError",
                    "correct": True,
                    "feedback": "Richtig! sort() ist eine void Funktion und hat den Rückgabewert None. Die folgende Operation a[0] ist dann nicht mehr erlaubt!"
                },
            ]
    }]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from jupyterquiz import display_quiz
#       2 display_quiz("quiz_variables.json", colors='fdsp')
#
# ModuleNotFoundError: No module named 'jupyterquiz'

# %%
display_quiz(q1, colors='fdsp')
display_quiz(q2, colors='fdsp')
display_quiz(q3, colors='fdsp')
display_quiz(q4, colors='fdsp')
display_quiz(q5, colors='fdsp')
display_quiz(q6, colors='fdsp')
